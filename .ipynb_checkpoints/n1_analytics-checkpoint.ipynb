# %%
import sqlite3

# %%
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# to preface, the data given currently has the 500 cities data "df500" (health information for each tract and fips id),
# the access data from the food atlas "food_atlas" (access variable measures for each county), variable list "var_list"(information about the variables and how they are measured like count vs percentage), and I will also add the 500 cities tract shape files for graphing in maps as a gpd file "tracts"

# %% [markdown]
# **We will start with loading the data, understanding the datasets, and cleaning/merging as needed**

# %%
conn = sqlite3.connect("challenge.db")

# %%
schema = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
schema
# Out:
#                   name
# 0  five_hundred_cities
# 1               access
# 2        variable_list

# %%
df500 = pd.read_sql("SELECT * FROM five_hundred_cities;", conn)

# %%
df500.head()
# Out:
#    index StateAbbr   PlaceName  PlaceFIPS   TractFIPS        Place_TractID  \
# 0      0        AL  Birmingham     107000  1073000100  0107000-01073000100
# 1      1        AL  Birmingham     107000  1073000300  0107000-01073000300
# 2      2        AL  Birmingham     107000  1073000400  0107000-01073000400
# 3      3        AL  Birmingham     107000  1073000500  0107000-01073000500
# 4      4        AL  Birmingham     107000  1073000700  0107000-01073000700
#
#    Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0            3042               24.4      (21.2, 27.8)                 31.2
# 1            2735               30.4      (27.1, 33.7)                 30.5
# 2            3338               24.7      (21.1, 28.5)                 31.5
# 3            2864               25.2      (21.6, 29.0)                 35.0
# 4            2577               29.0      (24.5, 33.8)                 36.3
#
#    ... PAPTEST_Crude95CI  PHLTH_CrudePrev PHLTH_Crude95CI  SLEEP_CrudePrev  \
# 0  ...      (83.4, 86.6)             20.5    (18.9, 22.2)             45.5
# 1  ...      (81.9, 85.6)             22.2    (20.4, 24.0)             44.5
# 2  ...      (82.3, 86.8)             19.4    (17.5, 21.4)             45.7
# 3  ...      (82.1, 86.5)             21.7    (19.7, 23.9)             46.1
# 4  ...      (82.2, 87.1)             25.5    (23.1, 28.0)             48.3
#
#   SLEEP_Crude95CI  STROKE_CrudePrev STROKE_Crude95CI  TEETHLOST_CrudePrev  \
# 0    (44.3, 46.5)               5.5     ( 5.0,  5.9)                 28.9
# 1    (43.2, 45.7)               6.1     ( 5.5,  6.8)                 32.9
# 2    (44.2, 47.0)               5.6     ( 5.0,  6.2)                 28.6
# 3    (44.5, 47.4)               7.3     ( 6.5,  8.2)                 34.0
# 4    (46.6, 49.7)               9.0     ( 8.1, 10.0)                 43.2
#
#   TEETHLOST_Crude95CI                       Geolocation
# 0        (23.7, 35.1)  (33.57943283260, -86.7228323926)
# 1        (25.5, 40.2)  (33.54282086860, -86.7524339780)
# 2        (22.0, 35.1)  (33.56324496330, -86.7640474064)
# 3        (24.4, 42.9)  (33.54424045940, -86.7749130719)
# 4        (33.2, 53.2)  (33.55254061390, -86.8016893706)
#
# [5 rows x 64 columns]

# %% [markdown]
# The place fips has normally 7 digits, here it has 6 due to a missing leading 0. Add leading 0, then cut it to 5 digits

# %%
food_atlas = pd.read_sql("SELECT * FROM access;", conn)

# %%
food_atlas
# Out:
#       index   FIPS State      County  LACCESS_POP10  LACCESS_POP15  \
# 0         0   1001    AL     Autauga   18428.439685   17496.693038
# 1         1   1003    AL     Baldwin   35210.814078   30561.264430
# 2         2   1005    AL     Barbour    5722.305602    6069.523628
# 3         3   1007    AL        Bibb    1044.867327     969.378841
# 4         4   1009    AL      Blount    1548.175559    3724.428242
# ...     ...    ...   ...         ...            ...            ...
# 3138   3138  56037    WY  Sweetwater   13391.715505   18934.737809
# 3139   3139  56039    WY       Teton    6212.423697    6212.390430
# 3140   3140  56041    WY       Uinta    4270.147119    4686.017653
# 3141   3141  56043    WY    Washakie     931.411647     931.411647
# 3142   3142  56045    WY      Weston    1240.493102    1237.267037
#
#       PCH_LACCESS_POP_10_15  PCT_LACCESS_POP10  PCT_LACCESS_POP15  \
# 0                 -5.056026          33.769657          32.062255
# 1                -13.204891          19.318473          16.767489
# 2                  6.067799          20.840972          22.105560
# 3                 -7.224696           4.559753           4.230324
# 4                140.568857           2.700840           6.497380
# ...                     ...                ...                ...
# 3138              41.391428          30.570505          43.224074
# 3139              -0.000535          29.174527          29.174370
# 3140               9.739021          20.220414          22.189685
# 3141               0.000000          10.915407          10.915407
# 3142              -0.260063          17.209949          17.165192
#
#       LACCESS_LOWI10  ...  PCT_LACCESS_HISP15  LACCESS_NHASIAN15  \
# 0        5344.427472  ...            0.863345          86.767975
# 1        9952.144027  ...            0.755973         212.946378
# 2        3135.676086  ...            1.855183          17.096410
# 3         491.449066  ...            0.037516           1.994318
# 4         609.027708  ...            0.867886           8.428994
# ...              ...  ...                 ...                ...
# 3138     2414.618816  ...            6.075311         114.722086
# 3139     1059.463554  ...            3.457192          53.489780
# 3140     1518.415783  ...            2.536304          13.831709
# 3141      233.628356  ...            0.415733           6.366775
# 3142      287.543111  ...            0.389472           2.771750
#
#       PCT_LACCESS_NHASIAN15  LACCESS_NHNA15  PCT_LACCESS_NHNA15  \
# 0                  0.159000       61.169869            0.112092
# 1                  0.116833      181.649648            0.099662
# 2                  0.062266       39.960527            0.145539
# 3                  0.008703        2.513097            0.010967
# 4                  0.014705       28.938242            0.050484
# ...                     ...             ...                 ...
# 3138               0.261887      189.621441            0.432866
# 3139               0.251196       32.482255            0.152542
# 3140               0.065497       40.339658            0.191020
# 3141               0.074614        5.006976            0.058678
# 3142               0.038454       10.372147            0.143898
#
#       LACCESS_NHPI15  PCT_LACCESS_NHPI15  LACCESS_MULTIR15  \
# 0           8.817961            0.016159        482.848633
# 1          14.819634            0.008131       1127.696098
# 2           8.082376            0.029436        462.382655
# 3           0.000000            0.000000          5.259244
# 4           1.062851            0.001854        202.914187
# ...              ...                 ...               ...
# 3138       27.720443            0.063280       1605.391465
# 3139        8.468847            0.039771        460.434464
# 3140        6.586104            0.031187        350.320469
# 3141        0.000000            0.000000         34.160542
# 3142        0.507750            0.007044         24.811192
#
#       PCT_LACCESS_MULTIR15  county_fips
# 0                 0.884808        01001
# 1                 0.618712        01003
# 2                 1.684025        01005
# 3                 0.022951        01007
# 4                 0.353990        01009
# ...                    ...          ...
# 3138              3.664775        56037
# 3139              2.162273        56039
# 3140              1.658871        56041
# 3141              0.400334        56043
# 3142              0.344217        56045
#
# [3143 rows x 46 columns]

# %% [markdown]
# notice here that the fips codes are 4 digits, not the nromal 5 for county fips. This is due to a missing leading 0 which we can add in when combining the datasets

# %%
df500["TractFIPS"] = (
    df500["TractFIPS"]
    .astype(str)
    .str.zfill(11)
)

# %%
df500["PlaceFIPS"] = (
    df500["PlaceFIPS"]
    .astype(str)
    .str.zfill(7)
)

# %%
df500["TractFIPS"].str.len().value_counts()
# Out:
# TractFIPS
# 11    27210
# Name: count, dtype: int64

# %%
df500["county_fips"] = df500["TractFIPS"].str[:5]

# %%
df500["PlaceFIPS"].str.len().value_counts()
# Out:
# PlaceFIPS
# 7    27210
# Name: count, dtype: int64

# %%
df500
# Out:
#        index StateAbbr   PlaceName PlaceFIPS    TractFIPS  \
# 0          0        AL  Birmingham   0107000  01073000100
# 1          1        AL  Birmingham   0107000  01073000300
# 2          2        AL  Birmingham   0107000  01073000400
# 3          3        AL  Birmingham   0107000  01073000500
# 4          4        AL  Birmingham   0107000  01073000700
# ...      ...       ...         ...       ...          ...
# 27205  27205        WY    Cheyenne   5613900  56021001000
# 27206  27206        WY    Cheyenne   5613900  56021001200
# 27207  27207        WY    Cheyenne   5613900  56021001501
# 27208  27208        WY    Cheyenne   5613900  56021001502
# 27209  27209        WY    Cheyenne   5613900  56021002000
#
#              Place_TractID  Population2010  ACCESS2_CrudePrev  \
# 0      0107000-01073000100            3042               24.4
# 1      0107000-01073000300            2735               30.4
# 2      0107000-01073000400            3338               24.7
# 3      0107000-01073000500            2864               25.2
# 4      0107000-01073000700            2577               29.0
# ...                    ...             ...                ...
# 27205  5613900-56021001000            3026               17.2
# 27206  5613900-56021001200            4638                9.8
# 27207  5613900-56021001501            3312               14.5
# 27208  5613900-56021001502            4518               16.6
# 27209  5613900-56021002000             214               17.9
#
#       ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  ... PHLTH_CrudePrev  \
# 0          (21.2, 27.8)                 31.2  ...            20.5
# 1          (27.1, 33.7)                 30.5  ...            22.2
# 2          (21.1, 28.5)                 31.5  ...            19.4
# 3          (21.6, 29.0)                 35.0  ...            21.7
# 4          (24.5, 33.8)                 36.3  ...            25.5
# ...                 ...                  ...  ...             ...
# 27205      (14.9, 19.9)                 24.2  ...            12.2
# 27206      ( 7.8, 12.0)                 25.2  ...             8.8
# 27207      (12.9, 16.1)                 22.0  ...             9.6
# 27208      (14.3, 18.9)                 25.2  ...            12.0
# 27209      (15.4, 20.5)                 15.7  ...             8.5
#
#        PHLTH_Crude95CI SLEEP_CrudePrev  SLEEP_Crude95CI STROKE_CrudePrev  \
# 0         (18.9, 22.2)            45.5     (44.3, 46.5)              5.5
# 1         (20.4, 24.0)            44.5     (43.2, 45.7)              6.1
# 2         (17.5, 21.4)            45.7     (44.2, 47.0)              5.6
# 3         (19.7, 23.9)            46.1     (44.5, 47.4)              7.3
# 4         (23.1, 28.0)            48.3     (46.6, 49.7)              9.0
# ...                ...             ...              ...              ...
# 27205     (11.1, 13.4)            34.5     (33.0, 35.8)              3.0
# 27206     ( 7.6, 10.1)            29.0     (27.5, 30.7)              2.5
# 27207     ( 8.9, 10.4)            32.9     (31.9, 33.9)              2.3
# 27208     (10.8, 13.3)            34.8     (33.3, 36.1)              3.2
# 27209     ( 7.7,  9.3)            34.0     (32.5, 35.3)              1.7
#
#        STROKE_Crude95CI TEETHLOST_CrudePrev  TEETHLOST_Crude95CI  \
# 0          ( 5.0,  5.9)                28.9         (23.7, 35.1)
# 1          ( 5.5,  6.8)                32.9         (25.5, 40.2)
# 2          ( 5.0,  6.2)                28.6         (22.0, 35.1)
# 3          ( 6.5,  8.2)                34.0         (24.4, 42.9)
# 4          ( 8.1, 10.0)                43.2         (33.2, 53.2)
# ...                 ...                 ...                  ...
# 27205      ( 2.8,  3.3)                16.2         (11.4, 21.5)
# 27206      ( 2.2,  2.8)                 8.1         ( 4.7, 12.2)
# 27207      ( 2.2,  2.5)                11.9         ( 8.5, 15.9)
# 27208      ( 2.8,  3.6)                19.7         (13.1, 27.1)
# 27209      ( 1.5,  1.9)                13.7         ( 8.4, 20.4)
#
#                             Geolocation  county_fips
# 0      (33.57943283260, -86.7228323926)        01073
# 1      (33.54282086860, -86.7524339780)        01073
# 2      (33.56324496330, -86.7640474064)        01073
# 3      (33.54424045940, -86.7749130719)        01073
# 4      (33.55254061390, -86.8016893706)        01073
# ...                                 ...          ...
# 27205  (41.14141598330, -104.829095061)        56021
# 27206  (41.17926735060, -104.838572685)        56021
# 27207  (41.16037417080, -104.756560525)        56021
# 27208  (41.15063392830, -104.755675636)        56021
# 27209  (41.13361679520, -104.719053785)        56021
#
# [27210 rows x 65 columns]

# %%
var_list = pd.read_sql("SELECT * FROM variable_list;", conn)

# %%
print(df500.shape)
print(food_atlas.shape)
print(var_list.shape)
# Out:
# (27210, 64)
# (3143, 45)
# (281, 8)

# %%
#df500.info()

# %%
#food_atlas.info()

# %%
#var_list.info()

# %%
#add leading 0s to the fips codes 
food_atlas["county_fips"] = (food_atlas["FIPS"].astype(str).str.zfill(5))

# %%
food_atlas.head()
# Out:
#    index  FIPS State   County  LACCESS_POP10  LACCESS_POP15  \
# 0      0  1001    AL  Autauga   18428.439685   17496.693038
# 1      1  1003    AL  Baldwin   35210.814078   30561.264430
# 2      2  1005    AL  Barbour    5722.305602    6069.523628
# 3      3  1007    AL     Bibb    1044.867327     969.378841
# 4      4  1009    AL   Blount    1548.175559    3724.428242
#
#    PCH_LACCESS_POP_10_15  PCT_LACCESS_POP10  PCT_LACCESS_POP15  \
# 0              -5.056026          33.769657          32.062255
# 1             -13.204891          19.318473          16.767489
# 2               6.067799          20.840972          22.105560
# 3              -7.224696           4.559753           4.230324
# 4             140.568857           2.700840           6.497380
#
#    LACCESS_LOWI10  ...  PCT_LACCESS_HISP15  LACCESS_NHASIAN15  \
# 0     5344.427472  ...            0.863345          86.767975
# 1     9952.144027  ...            0.755973         212.946378
# 2     3135.676086  ...            1.855183          17.096410
# 3      491.449066  ...            0.037516           1.994318
# 4      609.027708  ...            0.867886           8.428994
#
#    PCT_LACCESS_NHASIAN15  LACCESS_NHNA15  PCT_LACCESS_NHNA15  LACCESS_NHPI15  \
# 0               0.159000       61.169869            0.112092        8.817961
# 1               0.116833      181.649648            0.099662       14.819634
# 2               0.062266       39.960527            0.145539        8.082376
# 3               0.008703        2.513097            0.010967        0.000000
# 4               0.014705       28.938242            0.050484        1.062851
#
#    PCT_LACCESS_NHPI15  LACCESS_MULTIR15  PCT_LACCESS_MULTIR15  county_fips
# 0            0.016159        482.848633              0.884808        01001
# 1            0.008131       1127.696098              0.618712        01003
# 2            0.029436        462.382655              1.684025        01005
# 3            0.000000          5.259244              0.022951        01007
# 4            0.001854        202.914187              0.353990        01009
#
# [5 rows x 46 columns]

# %% [markdown]
# going to do a left merge onto the city dataset since it is at tract level and food atlas is at county level, and each county has multiple tracts so we can assign many city values(tracts) to one food atlas value(county)

# %%
city_and_atlas = df500.merge(
    food_atlas,
    on="county_fips",
    how="left",
    validate="many_to_one"
)

# %%
id_cols = ['index', 'FIPS', 'State', 'County']
food_vars = [c for c in food_atlas.columns if c not in id_cols]
matched_vars = var_list[var_list['Variable Code'].isin(food_vars)]
matched_vars[
    ['Variable Code', 'Variable Name', 'Category Name', 'Category Code', 'Units']
].sort_values('Category Name')
#print("done")
# Out:
#                 Variable Code  \
# 0               LACCESS_POP10
# 23          LACCESS_SENIORS15
# 24  PCH_LACCESS_SENIORS_10_15
# 25      PCT_LACCESS_SENIORS10
# 26      PCT_LACCESS_SENIORS15
# 27            LACCESS_WHITE15
# 28        PCT_LACCESS_WHITE15
# 29            LACCESS_BLACK15
# 22          LACCESS_SENIORS10
# 30        PCT_LACCESS_BLACK15
# 32         PCT_LACCESS_HISP15
# 33          LACCESS_NHASIAN15
# 34      PCT_LACCESS_NHASIAN15
# 35             LACCESS_NHNA15
# 36         PCT_LACCESS_NHNA15
# 37             LACCESS_NHPI15
# 38         PCT_LACCESS_NHPI15
# 31             LACCESS_HISP15
# 21        PCT_LACCESS_CHILD15
# 20        PCT_LACCESS_CHILD10
# 18            LACCESS_CHILD15
# 1               LACCESS_POP15
# 2       PCH_LACCESS_POP_10_15
# 3           PCT_LACCESS_POP10
# 4           PCT_LACCESS_POP15
# 5              LACCESS_LOWI10
# 6              LACCESS_LOWI15
# 7      PCH_LACCESS_LOWI_10_15
# 8          PCT_LACCESS_LOWI10
# 9          PCT_LACCESS_LOWI15
# 10             LACCESS_HHNV10
# 11             LACCESS_HHNV15
# 12     PCH_LACCESS_HHNV_10_15
# 13         PCT_LACCESS_HHNV10
# 14         PCT_LACCESS_HHNV15
# 15             LACCESS_SNAP15
# 16         PCT_LACCESS_SNAP15
# 17            LACCESS_CHILD10
# 39           LACCESS_MULTIR15
# 40       PCT_LACCESS_MULTIR15
#
#                                         Variable Name  \
# 0               Population, low access to store, 2010
# 23                 Seniors, low access to store, 2015
# 24  Seniors, low access to store (% change), 2010 -15
# 25             Seniors, low access to store (%), 2010
# 26             Seniors, low access to store (%), 2015
# 27                   White, low access to store, 2015
# 28               White, low access to store (%), 2015
# 29                   Black, low access to store, 2015
# 22                 Seniors, low access to store, 2010
# 30               Black, low access to store (%), 2015
# 32  Hispanic ethnicity, low access to store (%), 2015
# 33                   Asian, low access to store, 2015
# 34               Asian, low access to store (%), 2015
# 35  American Indian or Alaska Native, low access t...
# 36  American Indian or Alaska Native, low access t...
# 37  Hawaiian or Pacific Islander, low access to st...
# 38  Hawaiian or Pacific Islander, low access to st...
# 31      Hispanic ethnicity, low access to store, 2015
# 21            Children, low access to store (%), 2015
# 20            Children, low access to store (%), 2010
# 18                Children, low access to store, 2015
# 1               Population, low access to store, 2015
# 2   Population, low access to store (% change), 20...
# 3           Population, low access to store (%), 2010
# 4           Population, low access to store (%), 2015
# 5              Low income & low access to store, 2010
# 6              Low income & low access to store, 2015
# 7   Low income & low access to store (% change), 2...
# 8          Low income & low access to store (%), 2010
# 9          Low income & low access to store (%), 2015
# 10     Households, no car & low access to store, 2010
# 11     Households, no car & low access to store, 2015
# 12  Households, no car & low access to store (% ch...
# 13  Households, no car & low access to store (%), ...
# 14  Households, no car & low access to store (%), ...
# 15         SNAP households, low access to store, 2015
# 16     SNAP households, low access to store (%), 2015
# 17                Children, low access to store, 2010
# 39             Multiracial, low access to store, 2015
# 40         Multiracial, low access to store (%), 2015
#
#                             Category Name Category Code     Units
# 0   Access and Proximity to Grocery Store        ACCESS     Count
# 23  Access and Proximity to Grocery Store        ACCESS     Count
# 24  Access and Proximity to Grocery Store        ACCESS  % change
# 25  Access and Proximity to Grocery Store        ACCESS   Percent
# 26  Access and Proximity to Grocery Store        ACCESS   Percent
# 27  Access and Proximity to Grocery Store        ACCESS     Count
# 28  Access and Proximity to Grocery Store        ACCESS   Percent
# 29  Access and Proximity to Grocery Store        ACCESS     Count
# 22  Access and Proximity to Grocery Store        ACCESS     Count
# 30  Access and Proximity to Grocery Store        ACCESS   Percent
# 32  Access and Proximity to Grocery Store        ACCESS   Percent
# 33  Access and Proximity to Grocery Store        ACCESS     Count
# 34  Access and Proximity to Grocery Store        ACCESS   Percent
# 35  Access and Proximity to Grocery Store        ACCESS     Count
# 36  Access and Proximity to Grocery Store        ACCESS   Percent
# 37  Access and Proximity to Grocery Store        ACCESS     Count
# 38  Access and Proximity to Grocery Store        ACCESS   Percent
# 31  Access and Proximity to Grocery Store        ACCESS     Count
# 21  Access and Proximity to Grocery Store        ACCESS   Percent
# 20  Access and Proximity to Grocery Store        ACCESS   Percent
# 18  Access and Proximity to Grocery Store        ACCESS     Count
# 1   Access and Proximity to Grocery Store        ACCESS     Count
# 2   Access and Proximity to Grocery Store        ACCESS  % change
# 3   Access and Proximity to Grocery Store        ACCESS   Percent
# 4   Access and Proximity to Grocery Store        ACCESS   Percent
# 5   Access and Proximity to Grocery Store        ACCESS     Count
# 6   Access and Proximity to Grocery Store        ACCESS     Count
# 7   Access and Proximity to Grocery Store        ACCESS  % change
# 8   Access and Proximity to Grocery Store        ACCESS   Percent
# 9   Access and Proximity to Grocery Store        ACCESS   Percent
# 10  Access and Proximity to Grocery Store        ACCESS     Count
# 11  Access and Proximity to Grocery Store        ACCESS     Count
# 12  Access and Proximity to Grocery Store        ACCESS  % change
# 13  Access and Proximity to Grocery Store        ACCESS   Percent
# 14  Access and Proximity to Grocery Store        ACCESS   Percent
# 15  Access and Proximity to Grocery Store        ACCESS     Count
# 16  Access and Proximity to Grocery Store        ACCESS   Percent
# 17  Access and Proximity to Grocery Store        ACCESS     Count
# 39  Access and Proximity to Grocery Store        ACCESS     Count
# 40  Access and Proximity to Grocery Store        ACCESS   Percent

# %%
city_and_atlas.columns
# Out:
# Index(['index_x', 'StateAbbr', 'PlaceName', 'PlaceFIPS', 'TractFIPS',
#        'Place_TractID', 'Population2010', 'ACCESS2_CrudePrev',
#        'ACCESS2_Crude95CI', 'ARTHRITIS_CrudePrev',
#        ...
#        'LACCESS_HISP15', 'PCT_LACCESS_HISP15', 'LACCESS_NHASIAN15',
#        'PCT_LACCESS_NHASIAN15', 'LACCESS_NHNA15', 'PCT_LACCESS_NHNA15',
#        'LACCESS_NHPI15', 'PCT_LACCESS_NHPI15', 'LACCESS_MULTIR15',
#        'PCT_LACCESS_MULTIR15'],
#       dtype='object', length=110)

# %% [markdown]
# We now have tract level df with the geo labels and IDs are given with StateAbbr PlaceName and TractFIPS
# Now that there are around 110 variables, we can look at nutrition sensitive health variables to keep.
# Also need to decide how to deal with percentage vs counts

# %% [markdown]
# Based off of the question at hand, we have chosen health indicators that are nutrition dependent, as well as access indicators to target different subpopulations.
#
# Health indicators = PHLTH_CrudePrev, STROKE_CrudePrev, OBESITY_CrudePrev, HIGHCHOL_CrudePrev, DIABETES_CrudePrev, CHOLSCREEN_CrudePrev, CHD_CrudePrev, BPMED_CrudePrev, BPHIGH_CrudePrev (all number vars)
#
# access labels = LACCESS_POP10, LACCESS_SENIORS10, LACCESS_LOWI10, LACCESS_HHNV10, LACCESS_CHILD10 and corresponding percentages for the access intensity. counts will be for population burden/scale

# %% [markdown]
# **Here we have also read in the .shp files and loaded them into geopandas**

# %%
tracts = gpd.read_file("500Cities_Tracts/500Cities_Tracts_Clip.shp")
tracts.head()
# Out:
#   place2010    tract2010  ST   PlaceName           plctract10  PlcTrPop10  \
# 0   0107000  01073000100  01  Birmingham  0107000-01073000100        3042
# 1   0107000  01073000300  01  Birmingham  0107000-01073000300        2735
# 2   0107000  01073000400  01  Birmingham  0107000-01073000400        3338
# 3   0107000  01073000500  01  Birmingham  0107000-01073000500        2864
# 4   0107000  01073000700  01  Birmingham  0107000-01073000700        2577
#
#                                             geometry
# 0  POLYGON ((-9653001.056 3974630.899, -9652982.0...
# 1  POLYGON ((-9657462.853 3968794.996, -9657470.2...
# 2  POLYGON ((-9657275.613 3972217.16, -9657275.39...
# 3  POLYGON ((-9660666.406 3968887.964, -9660631.7...
# 4  POLYGON ((-9661391.097 3968591.429, -9661398.2...

# %%
tracts.crs
tracts.columns
# Out:
# Index(['place2010', 'tract2010', 'ST', 'PlaceName', 'plctract10', 'PlcTrPop10',
#        'geometry'],
#       dtype='object')

# %% [markdown]
# **From here we will:**
# 1. create a new dataset with only the variables we chose to look at
# 2. Further reduce redundancy with correlation and select the more affected subgroups to focus on
# 3. Standardize health and food access variables to create priority indeces
# 4. sum counts to estimate population impact
# 5. run subgroup ID using k-means or EN
# 6. merge with tracts and make maps

# %%
health_vars = [
    'PHLTH_CrudePrev','STROKE_CrudePrev','OBESITY_CrudePrev','HIGHCHOL_CrudePrev',
    'DIABETES_CrudePrev','CHOLSCREEN_CrudePrev','CHD_CrudePrev','BPMED_CrudePrev','BPHIGH_CrudePrev']

food_pct_vars = [
    'PCT_LACCESS_POP10','PCT_LACCESS_SENIORS10','PCT_LACCESS_LOWI10',
    'PCT_LACCESS_HHNV10','PCT_LACCESS_CHILD10'
]

food_count_vars = [
    'LACCESS_POP10','LACCESS_SENIORS10','LACCESS_LOWI10',
    'LACCESS_HHNV10','LACCESS_CHILD10'
]

id_vars = ['TractFIPS','PlaceFIPS','State','PlaceName','Population2010', 'county_fips']

# %%
candidate_vars = id_vars + health_vars + food_pct_vars + food_count_vars

# %%
df_candidate = city_and_atlas[candidate_vars].copy()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_candidate[health_vars].corr(), annot=True, cmap='coolwarm')
plt.title("Health Variable Correlation")
plt.show()

# %% [markdown]
# Thinking of removing BPMED and CHOLSCREEN because those are preventative and addressing methods, not statistics of measure. I am going to use r<|0.85| as a high correlation threshold. Here, we see stroke and diabetes have a strong correlation, stroke and high bp have a high correlation, stroke and chronic heart disease have a high correlation, high plth and diabetes correlation, high plth and stroke correlation, high diabetes and bp correlation, high diabetes and chd correlation, high chd and bp correlation, high chd and diabetes correlation, high chd and stroke correlation. We can see clusters of correlated variables, where stroke, chd, and high bp are correlated, diabetes, obesity, and high bp are correlated, phlth, diabetes, and stroke are highly correlated

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_candidate[food_pct_vars].corr(), annot=True, cmap='coolwarm')
plt.title("Food Access % Variable Correlation")
plt.show()

# %%
health = df_candidate[health_vars]
food_pct = df_candidate[food_pct_vars]

# Or full health x food matrix
corr_matrix = pd.concat([health, food_pct], axis=1).corr()
sns.heatmap(corr_matrix.loc[health.columns, food_pct.columns], annot=True, cmap='coolwarm')
plt.title("Health vs Food Access % Correlations")
plt.show()

# %% [markdown]
# Looks here like we can definitely drop the cholscreen and bpmed (as they can also be driven by healthcare access and insurance coverage) from health variables, but we want to track all population subgroups so we won't drop those subgroups.

# %%
df_candidate
# Out:
#          TractFIPS PlaceFIPS State   PlaceName  Population2010 county_fips  \
# 0      01073000100   0107000    AL  Birmingham            3042       01073
# 1      01073000300   0107000    AL  Birmingham            2735       01073
# 2      01073000400   0107000    AL  Birmingham            3338       01073
# 3      01073000500   0107000    AL  Birmingham            2864       01073
# 4      01073000700   0107000    AL  Birmingham            2577       01073
# ...            ...       ...   ...         ...             ...         ...
# 27205  56021001000   5613900    WY    Cheyenne            3026       56021
# 27206  56021001200   5613900    WY    Cheyenne            4638       56021
# 27207  56021001501   5613900    WY    Cheyenne            3312       56021
# 27208  56021001502   5613900    WY    Cheyenne            4518       56021
# 27209  56021002000   5613900    WY    Cheyenne             214       56021
#
#        PHLTH_CrudePrev  STROKE_CrudePrev  OBESITY_CrudePrev  \
# 0                 20.5               5.5               46.4
# 1                 22.2               6.1               47.8
# 2                 19.4               5.6               45.7
# 3                 21.7               7.3               48.0
# 4                 25.5               9.0               52.7
# ...                ...               ...                ...
# 27205             12.2               3.0               31.7
# 27206              8.8               2.5               25.4
# 27207              9.6               2.3               27.7
# 27208             12.0               3.2               30.9
# 27209              8.5               1.7               27.2
#
#        HIGHCHOL_CrudePrev  ...  PCT_LACCESS_POP10  PCT_LACCESS_SENIORS10  \
# 0                    35.3  ...          31.780146               4.077738
# 1                    36.8  ...          31.780146               4.077738
# 2                    35.6  ...          31.780146               4.077738
# 3                    38.4  ...          31.780146               4.077738
# 4                    39.0  ...          31.780146               4.077738
# ...                   ...  ...                ...                    ...
# 27205                31.6  ...          24.092625               2.514663
# 27206                32.9  ...          24.092625               2.514663
# 27207                29.1  ...          24.092625               2.514663
# 27208                31.9  ...          24.092625               2.514663
# 27209                22.7  ...          24.092625               2.514663
#
#        PCT_LACCESS_LOWI10  PCT_LACCESS_HHNV10  PCT_LACCESS_CHILD10  \
# 0               11.421992            2.860118             7.626665
# 1               11.421992            2.860118             7.626665
# 2               11.421992            2.860118             7.626665
# 3               11.421992            2.860118             7.626665
# 4               11.421992            2.860118             7.626665
# ...                   ...                 ...                  ...
# 27205            5.918249            0.697813             6.398362
# 27206            5.918249            0.697813             6.398362
# 27207            5.918249            0.697813             6.398362
# 27208            5.918249            0.697813             6.398362
# 27209            5.918249            0.697813             6.398362
#
#        LACCESS_POP10  LACCESS_SENIORS10  LACCESS_LOWI10  LACCESS_HHNV10  \
# 0      209261.458662       26850.516562    75209.934064     7538.355680
# 1      209261.458662       26850.516562    75209.934064     7538.355680
# 2      209261.458662       26850.516562    75209.934064     7538.355680
# 3      209261.458662       26850.516562    75209.934064     7538.355680
# 4      209261.458662       26850.516562    75209.934064     7538.355680
# ...              ...                ...             ...             ...
# 27205   22102.092155        2306.901443     5429.283062      262.210062
# 27206   22102.092155        2306.901443     5429.283062      262.210062
# 27207   22102.092155        2306.901443     5429.283062      262.210062
# 27208   22102.092155        2306.901443     5429.283062      262.210062
# 27209   22102.092155        2306.901443     5429.283062      262.210062
#
#        LACCESS_CHILD10
# 0         50218.994905
# 1         50218.994905
# 2         50218.994905
# 3         50218.994905
# 4         50218.994905
# ...                ...
# 27205      5869.729459
# 27206      5869.729459
# 27207      5869.729459
# 27208      5869.729459
# 27209      5869.729459
#
# [27210 rows x 25 columns]

# %%
cols_to_drop = [
    'STROKE_CrudePrev',
    'CHOLSCREEN_CrudePrev',
    'CHD_CrudePrev',
    'BPMED_CrudePrev'
]

df_candidate = df_candidate.drop(columns=cols_to_drop, errors='ignore')

# %%
df_candidate
# Out:
#          TractFIPS PlaceFIPS State   PlaceName  Population2010 county_fips  \
# 0      01073000100   0107000    AL  Birmingham            3042       01073
# 1      01073000300   0107000    AL  Birmingham            2735       01073
# 2      01073000400   0107000    AL  Birmingham            3338       01073
# 3      01073000500   0107000    AL  Birmingham            2864       01073
# 4      01073000700   0107000    AL  Birmingham            2577       01073
# ...            ...       ...   ...         ...             ...         ...
# 27205  56021001000   5613900    WY    Cheyenne            3026       56021
# 27206  56021001200   5613900    WY    Cheyenne            4638       56021
# 27207  56021001501   5613900    WY    Cheyenne            3312       56021
# 27208  56021001502   5613900    WY    Cheyenne            4518       56021
# 27209  56021002000   5613900    WY    Cheyenne             214       56021
#
#        PHLTH_CrudePrev  OBESITY_CrudePrev  HIGHCHOL_CrudePrev  \
# 0                 20.5               46.4                35.3
# 1                 22.2               47.8                36.8
# 2                 19.4               45.7                35.6
# 3                 21.7               48.0                38.4
# 4                 25.5               52.7                39.0
# ...                ...                ...                 ...
# 27205             12.2               31.7                31.6
# 27206              8.8               25.4                32.9
# 27207              9.6               27.7                29.1
# 27208             12.0               30.9                31.9
# 27209              8.5               27.2                22.7
#
#        DIABETES_CrudePrev  ...  PCT_LACCESS_POP10  PCT_LACCESS_SENIORS10  \
# 0                    17.4  ...          31.780146               4.077738
# 1                    19.8  ...          31.780146               4.077738
# 2                    18.4  ...          31.780146               4.077738
# 3                    22.4  ...          31.780146               4.077738
# 4                    25.0  ...          31.780146               4.077738
# ...                   ...  ...                ...                    ...
# 27205                 9.7  ...          24.092625               2.514663
# 27206                 8.1  ...          24.092625               2.514663
# 27207                 7.4  ...          24.092625               2.514663
# 27208                 9.4  ...          24.092625               2.514663
# 27209                 5.0  ...          24.092625               2.514663
#
#        PCT_LACCESS_LOWI10  PCT_LACCESS_HHNV10  PCT_LACCESS_CHILD10  \
# 0               11.421992            2.860118             7.626665
# 1               11.421992            2.860118             7.626665
# 2               11.421992            2.860118             7.626665
# 3               11.421992            2.860118             7.626665
# 4               11.421992            2.860118             7.626665
# ...                   ...                 ...                  ...
# 27205            5.918249            0.697813             6.398362
# 27206            5.918249            0.697813             6.398362
# 27207            5.918249            0.697813             6.398362
# 27208            5.918249            0.697813             6.398362
# 27209            5.918249            0.697813             6.398362
#
#        LACCESS_POP10  LACCESS_SENIORS10  LACCESS_LOWI10  LACCESS_HHNV10  \
# 0      209261.458662       26850.516562    75209.934064     7538.355680
# 1      209261.458662       26850.516562    75209.934064     7538.355680
# 2      209261.458662       26850.516562    75209.934064     7538.355680
# 3      209261.458662       26850.516562    75209.934064     7538.355680
# 4      209261.458662       26850.516562    75209.934064     7538.355680
# ...              ...                ...             ...             ...
# 27205   22102.092155        2306.901443     5429.283062      262.210062
# 27206   22102.092155        2306.901443     5429.283062      262.210062
# 27207   22102.092155        2306.901443     5429.283062      262.210062
# 27208   22102.092155        2306.901443     5429.283062      262.210062
# 27209   22102.092155        2306.901443     5429.283062      262.210062
#
#        LACCESS_CHILD10
# 0         50218.994905
# 1         50218.994905
# 2         50218.994905
# 3         50218.994905
# 4         50218.994905
# ...                ...
# 27205      5869.729459
# 27206      5869.729459
# 27207      5869.729459
# 27208      5869.729459
# 27209      5869.729459
#
# [27210 rows x 21 columns]

# %%
df_candidate.columns
# Out:
# Index(['TractFIPS', 'PlaceFIPS', 'State', 'PlaceName', 'Population2010',
#        'county_fips', 'PHLTH_CrudePrev', 'OBESITY_CrudePrev',
#        'HIGHCHOL_CrudePrev', 'DIABETES_CrudePrev', 'BPHIGH_CrudePrev',
#        'PCT_LACCESS_POP10', 'PCT_LACCESS_SENIORS10', 'PCT_LACCESS_LOWI10',
#        'PCT_LACCESS_HHNV10', 'PCT_LACCESS_CHILD10', 'LACCESS_POP10',
#        'LACCESS_SENIORS10', 'LACCESS_LOWI10', 'LACCESS_HHNV10',
#        'LACCESS_CHILD10'],
#       dtype='object')

# %% [markdown]
# We can also drop PHLTH and HIGHCOL, but we will choose not to because high colesterol is an important indicator of nutrition, and physical health is an overal indicator of health and nutrition.

# %% [markdown]
# Going to continue using the analytical unit as the cencus tract, as we can join the mapping data to it.

# %% [markdown]
# going to create a column that scales and gets the average across the standardized health variables.

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np

# %%
health_vars = [
    'PHLTH_CrudePrev',
    'OBESITY_CrudePrev',
    'HIGHCHOL_CrudePrev',
    'DIABETES_CrudePrev',
    'BPHIGH_CrudePrev'
]

scaler = StandardScaler()

df_candidate['health_index'] = scaler.fit_transform(
    df_candidate[health_vars]
).mean(axis=1)

# %%
access_vars = {
    'overall': 'PCT_LACCESS_POP10',
    'seniors': 'PCT_LACCESS_SENIORS10',
    'low_income': 'PCT_LACCESS_LOWI10',
    'children': 'PCT_LACCESS_CHILD10',
    'no_vehicle': 'PCT_LACCESS_HHNV10'
}

for key, col in access_vars.items():
    df_candidate[f'access_index_{key}'] = scaler.fit_transform(
        df_candidate[[col]]
    )

# %%
for key in access_vars.keys():
    df_candidate[f'priority_index_{key}'] = (
        df_candidate['health_index']
        + df_candidate[f'access_index_{key}']
    )

# %%
for key, count_col in access_vars.items():
    df_candidate[f'impact_score_{key}'] = (
        df_candidate[f'priority_index_{key}'] * df_candidate[count_col]
    )

# %%
df_candidate
# Out:
#          TractFIPS PlaceFIPS State   PlaceName  Population2010 county_fips  \
# 0      01073000100   0107000    AL  Birmingham            3042       01073
# 1      01073000300   0107000    AL  Birmingham            2735       01073
# 2      01073000400   0107000    AL  Birmingham            3338       01073
# 3      01073000500   0107000    AL  Birmingham            2864       01073
# 4      01073000700   0107000    AL  Birmingham            2577       01073
# ...            ...       ...   ...         ...             ...         ...
# 27205  56021001000   5613900    WY    Cheyenne            3026       56021
# 27206  56021001200   5613900    WY    Cheyenne            4638       56021
# 27207  56021001501   5613900    WY    Cheyenne            3312       56021
# 27208  56021001502   5613900    WY    Cheyenne            4518       56021
# 27209  56021002000   5613900    WY    Cheyenne             214       56021
#
#        PHLTH_CrudePrev  OBESITY_CrudePrev  HIGHCHOL_CrudePrev  \
# 0                 20.5               46.4                35.3
# 1                 22.2               47.8                36.8
# 2                 19.4               45.7                35.6
# 3                 21.7               48.0                38.4
# 4                 25.5               52.7                39.0
# ...                ...                ...                 ...
# 27205             12.2               31.7                31.6
# 27206              8.8               25.4                32.9
# 27207              9.6               27.7                29.1
# 27208             12.0               30.9                31.9
# 27209              8.5               27.2                22.7
#
#        DIABETES_CrudePrev  ...  priority_index_overall  \
# 0                    17.4  ...                3.066297
# 1                    19.8  ...                3.371215
# 2                    18.4  ...                3.087353
# 3                    22.4  ...                3.681303
# 4                    25.0  ...                4.190152
# ...                   ...  ...                     ...
# 27205                 9.7  ...                0.630884
# 27206                 8.1  ...                0.275890
# 27207                 7.4  ...                0.103804
# 27208                 9.4  ...                0.609262
# 27209                 5.0  ...               -0.507105
#
#        priority_index_seniors  priority_index_low_income  \
# 0                    3.178935                   3.378339
# 1                    3.483853                   3.683257
# 2                    3.199991                   3.399396
# 3                    3.793941                   3.993345
# 4                    4.302790                   4.502195
# ...                       ...                        ...
# 27205                0.311601                   0.239564
# 27206               -0.043392                  -0.115429
# 27207               -0.215479                  -0.287516
# 27208                0.289979                   0.217942
# 27209               -0.826388                  -0.898425
#
#        priority_index_children  priority_index_no_vehicle  \
# 0                     2.860298                   3.714293
# 1                     3.165216                   4.019211
# 2                     2.881354                   3.735349
# 3                     3.475304                   4.329299
# 4                     3.984154                   4.838148
# ...                        ...                        ...
# 27205                 0.722090                  -0.522375
# 27206                 0.367096                  -0.877369
# 27207                 0.195010                  -1.049455
# 27208                 0.700467                  -0.543997
# 27209                -0.415900                  -1.660364
#
#        impact_score_overall  impact_score_seniors  impact_score_low_income  \
# 0                 97.447362             12.962862                38.587363
# 1                107.137701             14.206237                42.070134
# 2                 98.116544             13.048725                38.827871
# 3                116.992346             15.470695                45.611958
# 4                133.163659             17.545650                51.424033
# ...                     ...                   ...                      ...
# 27205             15.199654              0.783573                 1.417802
# 27206              6.646921             -0.109117                -0.683140
# 27207              2.500913             -0.541856                -1.701588
# 27208             14.678712              0.729199                 1.289835
# 27209            -12.217495             -2.078087                -5.317101
#
#        impact_score_children  impact_score_no_vehicle
# 0                  21.814533                10.623316
# 1                  24.140041                11.495417
# 2                  21.975125                10.683540
# 3                  26.504979                12.382306
# 4                  30.385804                13.837675
# ...                      ...                      ...
# 27205               4.620191                -0.364520
# 27206               2.348812                -0.612239
# 27207               1.247742                -0.732323
# 27208               4.481842                -0.379608
# 27209              -2.661077                -1.158623
#
# [27210 rows x 37 columns]

# %%
gdf = tracts.merge(
    df_candidate,
    left_on='tract2010',
    right_on='TractFIPS',  
    how='left'
)

# %%
gdf.columns
# Out:
# Index(['place2010', 'tract2010', 'ST', 'PlaceName_x', 'plctract10',
#        'PlcTrPop10', 'geometry', 'TractFIPS', 'PlaceFIPS', 'State',
#        'PlaceName_y', 'Population2010', 'county_fips', 'PHLTH_CrudePrev',
#        'OBESITY_CrudePrev', 'HIGHCHOL_CrudePrev', 'DIABETES_CrudePrev',
#        'BPHIGH_CrudePrev', 'PCT_LACCESS_POP10', 'PCT_LACCESS_SENIORS10',
#        'PCT_LACCESS_LOWI10', 'PCT_LACCESS_HHNV10', 'PCT_LACCESS_CHILD10',
#        'LACCESS_POP10', 'LACCESS_SENIORS10', 'LACCESS_LOWI10',
#        'LACCESS_HHNV10', 'LACCESS_CHILD10', 'health_index',
#        'access_index_overall', 'access_index_seniors',
#        'access_index_low_income', 'access_index_children',
#        'access_index_no_vehicle', 'priority_index_overall',
#        'priority_index_seniors', 'priority_index_low_income',
#        'priority_index_children', 'priority_index_no_vehicle',
#        'impact_score_overall', 'impact_score_seniors',
#        'impact_score_low_income', 'impact_score_children',
#        'impact_score_no_vehicle'],
#       dtype='object')

# %%
impact_summary = {
    key: df_candidate[f'impact_score_{key}'].sum() 
    for key in ['overall', 'seniors', 'low_income', 'children', 'no_vehicle']
}

# %%
impact_summary
# Out:
# {'overall': 324358.2498541039,
#  'seniors': 42709.38761399876,
#  'low_income': 126200.55058694672,
#  'children': 84788.402834437,
#  'no_vehicle': 28703.127067901838}

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

def plot_bubble_map(
    gdf, 
    value_col,              # Column to scale bubble size (priority or impact)
    color='red',            # Bubble color
    alpha=0.6,              # Transparency
    scale_factor=200,       # Multiply to adjust bubble size
    title=None,             # Map title
    subplot=False           # If True, return fig, ax for multi-panel plotting
):
    """
    Plots an enhanced bubble map with tract boundaries and proportional bubbles.
    
    Parameters:
    - gdf: GeoDataFrame with geometry (tract polygons) and centroids
    - value_col: Column name for bubble sizes
    - color: Bubble color
    - alpha: Transparency of bubbles
    - scale_factor: Multiply bubble sizes for visibility
    - title: Map title
    - subplot: If True, returns fig, ax
    """
    # Compute centroids if not already
    if 'centroid' not in gdf.columns:
        gdf['centroid'] = gdf.geometry.centroid
    gdf_points = gdf.set_geometry('centroid')
    
    fig, ax = plt.subplots(figsize=(12, 8))
    
    # Plot tract boundaries lightly
    gdf.plot(color='lightgrey', edgecolor='white', linewidth=0.3, ax=ax)
    
    # Plot bubbles
    gdf_points.plot(
        ax=ax,
        color=color,
        alpha=alpha,
        markersize=gdf_points[value_col] * scale_factor
    )
    
    # Title and clean axes
    if title:
        ax.set_title(title, fontsize=16)
    ax.axis('off')
    
    if subplot:
        return fig, ax
    else:
        plt.show()

# %%
#df_candidate.info()

# %% [markdown]
# Now, let's check out the subgroup population impact totals

# %%
import matplotlib.pyplot as plt

plt.bar(impact_summary.keys(), impact_summary.values())
plt.ylabel('Total Impact Score')
plt.title('Estimated Impact by Population Subgroup')
plt.show()

# %% [markdown]
# Health data doesnt directly reflect the current health of the child population. Children living in tracts where adults exhibit high nutrition-sensitive disease burden and food access constraints may face elevated risk of poor nutritional environments. explains problem 3.

# %%
gdf['centroid'] = gdf.geometry.centroid
gdf['x'] = gdf.centroid.x
gdf['y'] = gdf.centroid.y

# %%
gdf.columns
# Out:
# Index(['place2010', 'tract2010', 'ST', 'PlaceName_x', 'plctract10',
#        'PlcTrPop10', 'geometry', 'TractFIPS', 'PlaceFIPS', 'State',
#        'PlaceName_y', 'Population2010', 'county_fips', 'PHLTH_CrudePrev',
#        'OBESITY_CrudePrev', 'HIGHCHOL_CrudePrev', 'DIABETES_CrudePrev',
#        'BPHIGH_CrudePrev', 'PCT_LACCESS_POP10', 'PCT_LACCESS_SENIORS10',
#        'PCT_LACCESS_LOWI10', 'PCT_LACCESS_HHNV10', 'PCT_LACCESS_CHILD10',
#        'LACCESS_POP10', 'LACCESS_SENIORS10', 'LACCESS_LOWI10',
#        'LACCESS_HHNV10', 'LACCESS_CHILD10', 'health_index',
#        'access_index_overall', 'access_index_seniors',
#        'access_index_low_income', 'access_index_children',
#        'access_index_no_vehicle', 'priority_index_overall',
#        'priority_index_seniors', 'priority_index_low_income',
#        'priority_index_children', 'priority_index_no_vehicle',
#        'impact_score_overall', 'impact_score_seniors',
#        'impact_score_low_income', 'impact_score_children',
#        'impact_score_no_vehicle', 'centroid', 'x', 'y'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 12))

# Base map
gdf.boundary.plot(ax=ax, linewidth=0.3, color='lightgrey')

# Deployment priority bubbles
ax.scatter(
    gdf['x'],
    gdf['y'],
    s=gdf['impact_score_overall'] / gdf['impact_score_overall'].max() * 800,
    alpha=0.5
)

ax.set_title(
    'Food Access Deployment Priority\n(Size reflects population-weighted vulnerability)',
    fontsize=14
)
ax.axis('off')
plt.show()
# Out:
# /Users/nehabangalore/miniconda3/lib/python3.12/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df_sorted = df_candidate.sort_values(
    'impact_score_overall', ascending=False
).reset_index(drop=True)

df_sorted['cum_population'] = df_sorted['LACCESS_POP10'].cumsum()
df_sorted['cum_pct_population'] = (
    df_sorted['cum_population'] /
    df_sorted['LACCESS_POP10'].sum()
)

plt.plot(df_sorted['cum_pct_population'])
plt.axhline(0.5, linestyle='--')
plt.xlabel('Share of Tracts (Ranked by Priority)')
plt.ylabel('Cumulative Share of Affected Population')
plt.title('Concentration of Food Access Burden')
plt.show()

# %%
place_impact = (
    df_candidate
    .groupby('PlaceName')['impact_score_overall']
    .sum()
    .sort_values(ascending=False)
    .head(30)
)

place_impact.plot(kind='barh')
plt.title('Top Cities by Food Access Impact')
plt.xlabel('Total Impact Score')
plt.show()
#maybe we can start with 90% deployment tracts here as well. will do this for people count

# %%
place_impact = (
    df_candidate
    .groupby('PlaceName')['impact_score_overall']
    .sum()
    .sort_values(ascending=False)
    .tail(10)
)

place_impact.plot(kind='barh')
plt.title('Bottom Cities by Food Access Impact')
plt.xlabel('Total Impact Score')
plt.show()

# %% [markdown]
# Here we can see where we should avoid. These cites either do not have proximity issues in high concentrations for food access, or their health issue index is lower.

# %%
threshold = df_candidate['impact_score_overall'].quantile(0.90)

df_candidate['deploy_flag'] = (
    df_candidate['impact_score_overall'] >= threshold
)

# %%
included_population = {
    'overall': df_candidate.loc[df_candidate['deploy_flag'], 'LACCESS_POP10'].sum(),
    'seniors': df_candidate.loc[df_candidate['deploy_flag'], 'LACCESS_SENIORS10'].sum(),
    'low_income': df_candidate.loc[df_candidate['deploy_flag'], 'LACCESS_LOWI10'].sum(),
    'children': df_candidate.loc[df_candidate['deploy_flag'], 'LACCESS_CHILD10'].sum(),
    'no_vehicle': df_candidate.loc[df_candidate['deploy_flag'], 'LACCESS_HHNV10'].sum()
}

included_population
# Out:
# {'overall': 473354854.86012673,
#  'seniors': 55966020.27785198,
#  'low_income': 148995425.35986954,
#  'children': 121471929.81150956,
#  'no_vehicle': 12465597.973526638}

# %% [markdown]
# We are going to make the assumption that engagement liklihood will increase where severity and scale overlap

# %%
engagement_share = {
    'overall': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_overall'].sum()
               / df_candidate['impact_score_overall'].sum(),

    'low_income': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_low_income'].sum()
               / df_candidate['impact_score_low_income'].sum(),

    'seniors': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_seniors'].sum()
               / df_candidate['impact_score_seniors'].sum(),
    'children': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_children'].sum()
               / df_candidate['impact_score_children'].sum(),
    'no_vehicle': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_no_vehicle'].sum()
               / df_candidate['impact_score_no_vehicle'].sum()
}

engagement_share
# Out:
# {'overall': 0.6983482119606897,
#  'low_income': 0.6826161654985251,
#  'seniors': 0.6877484927889512,
#  'children': 0.6792709995043756,
#  'no_vehicle': 0.6521326784670275}

# %%
projected_impact = {
    'overall': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_overall'].sum(),
    'low_income': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_low_income'].sum(),
    'children': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_children'].sum(),
    'seniors': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_seniors'].sum(),
    'no_vehicle': df_candidate.loc[df_candidate['deploy_flag'], 'impact_score_no_vehicle'].sum()
    
}

projected_impact
# Out:
# {'overall': 226515.00382031212,
#  'low_income': 86146.53592546421,
#  'children': 57594.30313972766,
#  'seniors': 29373.31695946675,
#  'no_vehicle': 18718.247135170262}

# %%
projected_impact_pct = {
    k: v / df_candidate[f'impact_score_{k}'].sum()
    for k, v in projected_impact.items()
}

projected_impact_pct
# Out:
# {'overall': 0.6983482119606897,
#  'low_income': 0.6826161654985251,
#  'children': 0.6792709995043756,
#  'seniors': 0.6877484927889512,
#  'no_vehicle': 0.6521326784670275}

# %%
plt.figure()
plt.bar(included_population.keys(), included_population.values())
plt.title("Eligible Population Included in Deployment Areas")
plt.ylabel("Number of People")
plt.xlabel("Population Subgroup")
plt.show()

# %%
plt.figure()
plt.bar(engagement_share.keys(), engagement_share.values())
plt.axhline(0.10, linestyle='--')  # optional reference line
plt.title("Share of Total Need Captured by Deployment Areas")
plt.ylabel("Proportion of Total Impact Score")
plt.xlabel("Population Subgroup")
plt.show()

# %% [markdown]
# “Although we deploy to only 10% of tracts, we capture X–Y% of total food access need, suggesting strong engagement efficiency.”

# %%
plt.figure()
plt.bar(projected_impact.keys(), projected_impact.values())
plt.title("Projected Impact Score by Population Subgroup")
plt.ylabel("Impact Score (Relative Units)")
plt.xlabel("Population Subgroup")
plt.show()

# %%
summary_df = pd.DataFrame({
    'subgroup': ['overall', 'low_income', 'children', 'seniors', 'no_vehicle'],
    'included_population': [
        included_population['overall'],
        included_population['low_income'],
        included_population['children'],
        included_population['seniors'],
        included_population['no_vehicle']
    ],
    'impact_pct': [
        projected_impact_pct['overall'],
        projected_impact_pct['low_income'],
        projected_impact_pct['children'],
        projected_impact_pct['seniors'],
        projected_impact_pct['no_vehicle']
    ],
    'impact_abs': [
        projected_impact['overall'],
        projected_impact['low_income'],
        projected_impact['children'],
        projected_impact['seniors'],
        projected_impact['no_vehicle']
    ]
})

# %%
plot_df = summary_df[summary_df['subgroup'] != 'overall']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(9, 6))

plt.scatter(
    plot_df['included_population'],
    plot_df['impact_pct'],
    s=plot_df['impact_abs'] / plot_df['impact_abs'].max() * 1200 + 200,
    alpha=0.75
)

# Label each point
for _, row in plot_df.iterrows():
    plt.text(
        row['included_population'],
        row['impact_pct'],
        row['subgroup'],
        fontsize=11,
        ha='center',
        va='center'
    )

# Median reference lines (now meaningful)
plt.axvline(plot_df['included_population'].median(), linestyle='--', alpha=0.6)
plt.axhline(plot_df['impact_pct'].median(), linestyle='--', alpha=0.6)

plt.xlabel("Included Population (Scale)")
plt.ylabel("Share of Total Impact Captured (Efficiency)")
plt.title("Scale vs. Efficiency of Food Access Program\n(by Population Subgroup)")

plt.tight_layout()
plt.show()
